# %%
import matplotlib.pyplot as plt

# %% [markdown]
# We are plotting the data time vs distance

# %%
# Input your data here
x = [0,0,0,0,0]
y = [0,0,0,0,0]

# Fill in all the ?
plt.plot(x, y, label='?', marker='o')
plt.xlabel('?')
plt.ylabel('?')
plt.title('?')
plt.legend()
plt.show()
